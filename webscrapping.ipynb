# %% [markdown]
# <a href="https://colab.research.google.com/github/hsinha177/ML/blob/master/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Saprotrophic_nutrition'

# %%
#we r sending request to the url & taking the response
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Saprotrophic nutrition - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Saprotrophic_nutrition","wgTitle":"Saprotrophic nutrition","wgCurRevisionId":900115123,"wgRevisionId":900115123,"wgArticleId":8031008,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with unsourced statements","Articles with unsourced statements from March 2016","Nutrition","Mycology","Dead wood"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June
# ...

# %%
#parsing library -html.parser & second is lxml
soup = BeautifulSoup(response.text,'lxml')

# %%
for alink in soup.find_all('a'):
  #print(alink)
  #print(alink.get('href'))
# Out:
#   File "<ipython-input-16-8a390bfb18b7>", line 3
#     #print(alink.get('href'))
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
for ptag in soup.find_all('p'):
 # print(ptag)
  #now searching for b tag
  for btag in ptag.find_all('b'):
    print(btag.text)
# Out:
# Saprotrophic nutrition
# lysotrophic nutrition
# saprotrophs
# saprobes
# saprophytes
# facultative saprophyte

# %%
import pandas
import numpy as np

# %%
l=[['Harsh',2,3],['Shub',5,6],['Pika',8,9]]

# %%
df=pandas.DataFrame([l],columns=['Name','Age','Class'])
df
# Out:
#             Name           Age         Class
# 0  [Harsh, 2, 3]  [Shub, 5, 6]  [Pika, 8, 9]
