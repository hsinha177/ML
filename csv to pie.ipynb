# %%
import matplotlib.pyplot as ml  #imported matplot module as mi object
import pandas as pd  #imported panda module

ds=pd.read_csv("student.csv",header=None)   #read csv file & make its list

#creating pie chart for student & marks
ml.figure(0)#assigning position to pie to avoid overlapping of pie
ml.title("Student Marks :") #asigning title to pie
ml.pie(ds.iloc[1:,1],explode=(0.1,0.1,0.1,0.1),labels=df.iloc[1:,0],autopct="%1.2f%%",shadow=True) #draw pie

#creating pie chart for student & age
ml.figure(1)
ml.title("Student Age :")
ml.pie(ds.iloc[1:,2],explode=(0.1,0.1,0.1,0.1),labels=df.iloc[1:,0],autopct="%1.2f%%",shadow=True)

#creating pie chart for student & Study_hours
ml.figure(2)
ml.title("Student Study_hours :")
ml.pie(ds.iloc[1:,4],explode=(0.1,0.1,0.1,0.1),labels=df.iloc[1:,0],autopct="%1.2f%%",shadow=True)

ml.show() #to view the charts created

# %%
  `
